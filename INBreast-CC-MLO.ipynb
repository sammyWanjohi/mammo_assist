# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import pydicom
import imageio
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
inbreast_csv = pd.read_csv('/kaggle/input/inbreast-dataset/INbreast Release 1.0/INbreast.csv', delimiter=';')

# %%
inbreast_csv.head(3)
# Out:
#   Patient ID Patient age Laterality View  Acquisition date  File Name ACR  \
# 0    removed     removed          R   CC            201001   22678622   4
# 1    removed     removed          L   CC            201001   22678646   4
# 2    removed     removed          R  MLO            201001   22678670   4
#
#   Bi-Rads
# 0       1
# 1       3
# 2       1

# %%
final_dir = os.path.join('/kaggle/working/AllPNGs')
os.makedirs(final_dir, exist_ok=True)
# convert dicom to png 


directory = "/kaggle/input/inbreast-dataset/INbreast Release 1.0/AllDICOMs/"

for filename in os.listdir(directory):
    if filename.endswith(".dcm"): 
        ds = pydicom.dcmread(os.path.join(directory, filename))
        pixel_array = ds.pixel_array
        name_parts = filename.split("_")        
        new_filename = name_parts[0]
        output_path = f"/kaggle/working/AllPNGs/{new_filename}.png"
        imageio.imwrite(output_path, pixel_array)

# %%
os.listdir('/kaggle/input/inbreast-dataset/INbreast Release 1.0')
# Out:
# ['INbreast.csv',
#  'README.txt',
#  'inbreast.pdf',
#  'PectoralMuscle',
#  'INbreast.xls',
#  'AllXML',
#  'AllDICOMs',
#  'AllROI',
#  'MedicalReports']

# %%
inbreast_csv.rename(columns = {'Patient ID' : 'Patient_ID', "Patient age": "Patient_age",
    "Acquisition date": "Acquiition_date"})
# Out:
#     Patient_ID Patient_age Laterality View  Acquiition_date  File Name ACR  \
# 0      removed     removed          R   CC           201001   22678622   4
# 1      removed     removed          L   CC           201001   22678646   4
# 2      removed     removed          R  MLO           201001   22678670   4
# 3      removed     removed          L  MLO           201001   22678694   4
# 4      removed     removed          R   CC           201001   22614074   2
# ..         ...         ...        ...  ...              ...        ...  ..
# 405    removed     removed          L  MLO           201001   22613848   2
# 406    removed     removed          L  MLO           200802   24055725   4
# 407    removed     removed          R  MLO           200802   24055752   4
# 408    removed     removed          L   CC           200802   24055779   4
# 409    removed     removed          R   CC           200802   24055806   4
#
#     Bi-Rads
# 0         1
# 1         3
# 2         1
# 3         3
# 4         5
# ..      ...
# 405       1
# 406       2
# 407       2
# 408       2
# 409       2
#
# [410 rows x 8 columns]
